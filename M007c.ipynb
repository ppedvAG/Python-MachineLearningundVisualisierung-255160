# %% [markdown]
# ## Snake Modell

# %%
import gymnasium as gym
import numpy as np
import Snake
from gymnasium.spaces import Discrete, Box
from typing import Optional

# %%
class SnakePlayer(gym.Env):
    def __init__(self):
        self.game = Snake.SnakeGame()
        self.action_space = Discrete(4)
        self.observation_space = Box(0, 100, shape=(self.game.gridSize[0], self.game.gridSize[1]), dtype=np.int64)
        self.state = self.game.grid
        self.lastScore = 0
        
    def step(self, action):
        self.game.nextDirection = action

        self.game.step()

        reward = 0
        if self.game.score > self.lastScore:
            reward = 5
            self.lastScore = self.game.score

        self.state = self.game.grid

        return np.array(self.state), reward, self.game.death, False, {"Steps": self.game.steps, "Score": self.game.score}
    
    def reset(self, *, seed: Optional[int] = None, options: Optional[dict] = None,):
        if hasattr(self.game, "window"):
            try:
                self.game.window.destroy()
            except: pass
        
        self.game = Snake.SnakeGame()
        self.state = self.game.grid
        self.lastScore = 0
        return (np.array(self.state), {})
        
    def render(self):
        self.game.setupUI()
        self.game.window.update()
        pass
        
    def close(self):
        pass

    def rightDirection(self):
        game = self.game
        if game.headPosX > game.foodPos[1] and game.direction == 0:
            return True
        elif game.headPosX < game.foodPos[1] and game.direction == 2:
            return True
        elif game.headPosX == game.foodPos[1]:
            if game.headPosY > game.foodPos[0] and game.direction == 1:
                return True
            elif game.headPosY < game.foodPos[0] and game.direction == 3:
                return True
        return False

# %%
env = SnakePlayer()

# %%
durchgänge = 5  # Anzahl der Durchgänge
for i in range(durchgänge):  # Teste die Umgebung X mal
    state = env.reset()  # Setze die Umgebung für den nächsten Durchlauf zurück
    done = False  # Brich den Prozess ab, wenn z.B. die Zeit abläuft
    score = 0

    while not done:
        # env.render()  # Zeichne die Umgebung
        action = env.action_space.sample()  # Nimmt ein Random Element aus dem Action Space (Links oder Rechts)
        state, reward, done, term, info = env.step(action)  # state: Observation Space, reward: Belohnung, done: Fertig Ja/Nein, term: Termination (vorzeitiges Beenden), info: Extra Infos
        score += reward
    print(f"Durchgang {i}, Score: {score}, Info: {info}")
env.close()
# Out:
# Durchgang 0, Score: 0, Info: {'Steps': 49, 'Score': 0}
# Durchgang 1, Score: 0, Info: {'Steps': 44, 'Score': 0}
# Durchgang 2, Score: 0, Info: {'Steps': 114, 'Score': 0}
# Durchgang 3, Score: 0, Info: {'Steps': 45, 'Score': 0}
# Durchgang 4, Score: 0, Info: {'Steps': 28, 'Score': 0}

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env, warn=True)
# Out:
# C:\Users\lk3\source\repos\Python_DataScience_2025_04_16\.venv\Lib\site-packages\stable_baselines3\common\env_checker.py:272: UserWarning: Your observation  has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(

# %%
from stable_baselines3 import PPO

# %%
env = SnakePlayer()

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.7     |
# |    ep_rew_mean     | 0.366    |
# | time/              |          |
# |    fps             | 539      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.8        |
# |    ep_rew_mean          | 0.312       |
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.020792702 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -1.01       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0609     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0393     |
# |    value_loss           | 0.291       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.5        |
# |    ep_rew_mean          | 0.25        |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017265163 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.405      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0828     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0505     |
# |    value_loss           | 0.159       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | 0.45        |
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 4           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018287819 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.408      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0504     |
# |    value_loss           | 0.176       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.2        |
# |    ep_rew_mean          | 0.65        |
# | time/                   |             |
# |    fps                  | 310         |
# |    iterations           | 5           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016515296 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.197      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0476     |
# |    value_loss           | 0.429       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.4        |
# |    ep_rew_mean          | 0.6         |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 6           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020865127 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.471      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.159       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0565     |
# |    value_loss           | 0.334       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.5        |
# |    ep_rew_mean          | 0.65        |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 7           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.022412281 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.46       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0905      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0581     |
# |    value_loss           | 0.219       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.1        |
# |    ep_rew_mean          | 0.5         |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 8           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.023369575 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.314      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.203       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0556     |
# |    value_loss           | 0.181       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.4        |
# |    ep_rew_mean          | 0.55        |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 9           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.021566536 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -0.212      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0746      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0493     |
# |    value_loss           | 0.263       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.2        |
# |    ep_rew_mean          | 0.55        |
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 10          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.021174448 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -0.174      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.054       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0476     |
# |    value_loss           | 0.301       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.2       |
# |    ep_rew_mean          | 0.6        |
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 11         |
# |    time_elapsed         | 77         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02033174 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | -0.215     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0783     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0483    |
# |    value_loss           | 0.51       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50.1       |
# |    ep_rew_mean          | 0.25       |
# | time/                   |            |
# |    fps                  | 289        |
# |    iterations           | 12         |
# |    time_elapsed         | 85         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02438818 |
# |    clip_fraction        | 0.269      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | -0.355     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0144     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0548    |
# |    value_loss           | 0.292      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.1       |
# |    ep_rew_mean          | 0.45       |
# | time/                   |            |
# |    fps                  | 288        |
# |    iterations           | 13         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.02897954 |
# |    clip_fraction        | 0.297      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.12      |
# |    explained_variance   | -1.38      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0769    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0625    |
# |    value_loss           | 0.0744     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.5        |
# |    ep_rew_mean          | 0.45        |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 14          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.025389716 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0735     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0523      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0458     |
# |    value_loss           | 0.311       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.2        |
# |    ep_rew_mean          | 0.7         |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 15          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.023013465 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.11       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0997      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0465     |
# |    value_loss           | 0.378       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.8        |
# |    ep_rew_mean          | 0.75        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 16          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.024043165 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.303      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0548      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0499     |
# |    value_loss           | 0.351       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 77         |
# |    ep_rew_mean          | 0.75       |
# | time/                   |            |
# |    fps                  | 282        |
# |    iterations           | 17         |
# |    time_elapsed         | 123        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.02908003 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | -0.308     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0618    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0517    |
# |    value_loss           | 0.251      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80.8        |
# |    ep_rew_mean          | 0.7         |
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 18          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.027663488 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.999      |
# |    explained_variance   | -0.146      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00675    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 0.235       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.7        |
# |    ep_rew_mean          | 0.65        |
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 19          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.030172866 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | -0.221      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0548     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0479     |
# |    value_loss           | 0.284       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.8       |
# |    ep_rew_mean          | 0.55       |
# | time/                   |            |
# |    fps                  | 282        |
# |    iterations           | 20         |
# |    time_elapsed         | 145        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.03158297 |
# |    clip_fraction        | 0.292      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.938     |
# |    explained_variance   | -0.373     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0818    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0504    |
# |    value_loss           | 0.132      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 101        |
# |    ep_rew_mean          | 0.7        |
# | time/                   |            |
# |    fps                  | 282        |
# |    iterations           | 21         |
# |    time_elapsed         | 152        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.03135465 |
# |    clip_fraction        | 0.287      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.92      |
# |    explained_variance   | -0.215     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0942    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0471    |
# |    value_loss           | 0.149      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 108        |
# |    ep_rew_mean          | 0.65       |
# | time/                   |            |
# |    fps                  | 281        |
# |    iterations           | 22         |
# |    time_elapsed         | 160        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.02788715 |
# |    clip_fraction        | 0.259      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.886     |
# |    explained_variance   | -0.184     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0704     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0439    |
# |    value_loss           | 0.25       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | 0.9         |
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 23          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.029473428 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.862      |
# |    explained_variance   | -0.103      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.137       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0463     |
# |    value_loss           | 0.241       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 120        |
# |    ep_rew_mean          | 0.9        |
# | time/                   |            |
# |    fps                  | 281        |
# |    iterations           | 24         |
# |    time_elapsed         | 174        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.02896504 |
# |    clip_fraction        | 0.26       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.847     |
# |    explained_variance   | -0.177     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0361    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0445    |
# |    value_loss           | 0.403      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | 0.95        |
# | time/                   |             |
# |    fps                  | 279         |
# |    iterations           | 25          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.032402948 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.84       |
# |    explained_variance   | -0.661      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0385     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0491     |
# |    value_loss           | 0.161       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | 1.15        |
# | time/                   |             |
# |    fps                  | 279         |
# |    iterations           | 26          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.029753253 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.781      |
# |    explained_variance   | -0.324      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.102       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 0.245       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 133        |
# |    ep_rew_mean          | 1.25       |
# | time/                   |            |
# |    fps                  | 279        |
# |    iterations           | 27         |
# |    time_elapsed         | 198        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.02964124 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.778     |
# |    explained_variance   | -0.143     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.11       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0412    |
# |    value_loss           | 0.499      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 138        |
# |    ep_rew_mean          | 1.3        |
# | time/                   |            |
# |    fps                  | 278        |
# |    iterations           | 28         |
# |    time_elapsed         | 206        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.03273387 |
# |    clip_fraction        | 0.244      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.754     |
# |    explained_variance   | -0.603     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0408     |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0478    |
# |    value_loss           | 0.403      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 1.4         |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 29          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.032101743 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.744      |
# |    explained_variance   | -0.593      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0273     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0463     |
# |    value_loss           | 0.244       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | 1.4         |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 30          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.028177716 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.708      |
# |    explained_variance   | -0.111      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0347      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0376     |
# |    value_loss           | 0.416       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | 1.5         |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 31          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.033876598 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.704      |
# |    explained_variance   | -0.194      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0634      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.044      |
# |    value_loss           | 0.357       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 176         |
# |    ep_rew_mean          | 1.5         |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 32          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.036200054 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | -0.0151     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.118       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0415     |
# |    value_loss           | 0.265       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | 1.5         |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 33          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.037579164 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | -1.81       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0375     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 0.0837      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 198        |
# |    ep_rew_mean          | 1.6        |
# | time/                   |            |
# |    fps                  | 273        |
# |    iterations           | 34         |
# |    time_elapsed         | 254        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.04370628 |
# |    clip_fraction        | 0.291      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.645     |
# |    explained_variance   | -0.348     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0454    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0459    |
# |    value_loss           | 0.0744     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 213         |
# |    ep_rew_mean          | 1.6         |
# | time/                   |             |
# |    fps                  | 273         |
# |    iterations           | 35          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.032695524 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | -0.225      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0406     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0343     |
# |    value_loss           | 0.148       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 226         |
# |    ep_rew_mean          | 1.85        |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 36          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.029336533 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | -0.117      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.203       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0368     |
# |    value_loss           | 0.298       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 1.85        |
# | time/                   |             |
# |    fps                  | 271         |
# |    iterations           | 37          |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.029171893 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | -0.431      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0137      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0389     |
# |    value_loss           | 0.272       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 254        |
# |    ep_rew_mean          | 1.8        |
# | time/                   |            |
# |    fps                  | 270        |
# |    iterations           | 38         |
# |    time_elapsed         | 287        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.03230618 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.601     |
# |    explained_variance   | -1.11      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0518     |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0396    |
# |    value_loss           | 0.0958     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 268         |
# |    ep_rew_mean          | 1.95        |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 39          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.035951696 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | -0.275      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0363     |
# |    value_loss           | 0.114       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 286         |
# |    ep_rew_mean          | 1.9         |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 40          |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.030401915 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.602      |
# |    explained_variance   | -0.0553     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0665      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 0.209       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 303         |
# |    ep_rew_mean          | 1.85        |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 41          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.035698477 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | -1.84       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0433     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0446     |
# |    value_loss           | 0.0158      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 304       |
# |    ep_rew_mean          | 1.85      |
# | time/                   |           |
# |    fps                  | 268       |
# |    iterations           | 42        |
# |    time_elapsed         | 319       |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 0.0336546 |
# |    clip_fraction        | 0.263     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.61     |
# |    explained_variance   | -0.0894   |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.012    |
# |    n_updates            | 410       |
# |    policy_gradient_loss | -0.0339   |
# |    value_loss           | 0.042     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 304         |
# |    ep_rew_mean          | 1.85        |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 43          |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.028513158 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.106       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0308     |
# |    value_loss           | 0.163       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 327         |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 44          |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.032789625 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | -7.21       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0601     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0409     |
# |    value_loss           | 0.0147      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 338        |
# |    ep_rew_mean          | 1.8        |
# | time/                   |            |
# |    fps                  | 267        |
# |    iterations           | 45         |
# |    time_elapsed         | 344        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.03796364 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.608     |
# |    explained_variance   | 0.0273     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0499    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0305    |
# |    value_loss           | 0.135      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 350         |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 267         |
# |    iterations           | 46          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.039296277 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | -2.92       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0602     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0384     |
# |    value_loss           | 0.0199      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 381         |
# |    ep_rew_mean          | 1.75        |
# | time/                   |             |
# |    fps                  | 266         |
# |    iterations           | 47          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.029886488 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.572      |
# |    explained_variance   | -2.24       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0517     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0349     |
# |    value_loss           | 0.00755     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 394         |
# |    ep_rew_mean          | 1.7         |
# | time/                   |             |
# |    fps                  | 265         |
# |    iterations           | 48          |
# |    time_elapsed         | 369         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.034958497 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | 0.0446      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00589     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0301     |
# |    value_loss           | 0.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 406         |
# |    ep_rew_mean          | 1.7         |
# | time/                   |             |
# |    fps                  | 265         |
# |    iterations           | 49          |
# |    time_elapsed         | 377         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.025685381 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | -0.612      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0177      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0252     |
# |    value_loss           | 0.085       |
# -----------------------------------------

# %%
model.save("Models/Snake")

# %%
env = SnakePlayer()

# %%
model = PPO.load("Models/Snake", env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
durchgaenge = 10  # Anzahl Durchgänge der Umgebung
for d in range(durchgaenge):  # Teste die Umgebung X mal
    observation = env.reset()  # Setzt die Umgebung zurück und gibt einige Werte zurück
    done = False  # Umgebungen können Zeitlimitiert sein (hier 200ms)
    score = 0
    
    while not done:
        env.render()  # Zeichne die Umgebung (falls möglich)
        if len(observation) == 2:
            observation = observation[0]
        action, _ = model.predict(observation)  # 2 Parameter: Action, next State (in wiederkehrenden Modellen)
        observation, reward, done, term, info = env.step(action)
        score += reward
    print(f"Durchgang: {d}, Score: {score}, Steps: {info}")
env.close()
# Out:
# Durchgang: 0, Score: 0, Steps: {'Steps': 53, 'Score': 0}
# Durchgang: 1, Score: 0, Steps: {'Steps': 465, 'Score': 0}
# Durchgang: 2, Score: 0, Steps: {'Steps': 508, 'Score': 0}
# Durchgang: 3, Score: 0, Steps: {'Steps': 190, 'Score': 0}
# Durchgang: 4, Score: 5, Steps: {'Steps': 130, 'Score': 1}
# Durchgang: 5, Score: 5, Steps: {'Steps': 369, 'Score': 1}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 8
#       5 score = 0
#       7 while not done:
# ----> 8     env.render()  # Zeichne die Umgebung (falls möglich)
#       9     if len(observation) == 2:
#      10         observation = observation[0]
#
# Cell In[20], line 36, in SnakePlayer.render(self)
#      34 def render(self):
#      35     self.game.setupUI()
# ---> 36     self.game.window.update()
#      37     pass
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py:1373, in Misc.update(self)
#    1371 def update(self):
#    1372     """Enter event loop until all pending events have been processed by Tcl."""
# -> 1373     self.tk.call('update')
#
# KeyboardInterrupt:
