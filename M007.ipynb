# %% [markdown]
# ## Reinforcement Learning
#
# ML ohne vorgegebenes Datenset
#
# Das Datenset wird während des Prozesses erzeugt

# %%
import gymnasium as gym

# %% [markdown]
# ### Vordefinierte Umgebungen
#
# Es gibt von OpenAI vorgegebene Umgebungen, welche per RL automatisiert werden sollen
#
# https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
env = gym.make("CartPole-v1", render_mode="human")

# %% [markdown]
# ### Inhalte einer Umgebung
#
# - Action Space: Möglichen Aktionen, die der Agent ausführen darf (hier 0 und 1, links und rechts)
# - Observation Space: Beschreibt den Aufbau der Daten, die für das ML verwendet werden (hier siehe unten)
#
# | Num | Observation           | Min                 | Max               |
# |-----|-----------------------|---------------------|-------------------|
# | 0   | Cart Position         | -4.8                | 4.8               |
# | 1   | Cart Velocity         | -Inf                | Inf               |
# | 2   | Pole Angle            | ~ -0.418 rad (-24°) | ~ 0.418 rad (24°) |
# | 3   | Pole Angular Velocity | -Inf                | Inf               |

# %%
anz = 5
for x in range(anz):
    env = gym.make("CartPole-v1", render_mode="human")
    state = env.reset()  # Startzustand
    score = 0  # Reward Summe
    done = False
    
    while not done:
        env.render()  # Zeichnet die GUI
        action = env.action_space.sample()
        state, reward, done, _, _ = env.step(action)
        score += reward
    env.close()
    
    print(f"Punkte: {score}")
# Out:
# Punkte: 29.0
# Punkte: 11.0
# Punkte: 30.0
# Punkte: 17.0
# Punkte: 14.0

# %% [markdown]
# ### RL Modell trainieren
#
# Für das RL Modell benötigen wir einen Algorithmus
#
# Dieser wird hier PPO sein (stable-baselines3)
#
# Policy: Mlp (Multilayer Perceptron)
#
# MLP: Tensorflow Modell mit 2x 64 Dense Nodes

# %%
from stable_baselines3 import PPO
import numpy as np

# %%
env = gym.make("CartPole-v1")

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23       |
# |    ep_rew_mean     | 23       |
# | time/              |          |
# |    fps             | 2362     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | 29.7        |
# | time/                   |             |
# |    fps                  | 1500        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007850382 |
# |    clip_fraction        | 0.0952      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.00264    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.72        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 55.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.3        |
# |    ep_rew_mean          | 37.3        |
# | time/                   |             |
# |    fps                  | 1340        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008218502 |
# |    clip_fraction        | 0.0513      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.072       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 42.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.1        |
# |    ep_rew_mean          | 47.1        |
# | time/                   |             |
# |    fps                  | 1252        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007732968 |
# |    clip_fraction        | 0.0799      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | 0.192       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 57.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.9        |
# |    ep_rew_mean          | 56.9        |
# | time/                   |             |
# |    fps                  | 1188        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007344812 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.266       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 69.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 70.8         |
# |    ep_rew_mean          | 70.8         |
# | time/                   |              |
# |    fps                  | 1155         |
# |    iterations           | 6            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0074028578 |
# |    clip_fraction        | 0.0713       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.595       |
# |    explained_variance   | 0.4          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.7         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0127      |
# |    value_loss           | 65.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.6         |
# |    ep_rew_mean          | 87.6         |
# | time/                   |              |
# |    fps                  | 1130         |
# |    iterations           | 7            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0077700894 |
# |    clip_fraction        | 0.0913       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.585       |
# |    explained_variance   | 0.658        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.41         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0129      |
# |    value_loss           | 51.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 1108        |
# |    iterations           | 8           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006147446 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.91        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00685    |
# |    value_loss           | 29.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 122          |
# |    ep_rew_mean          | 122          |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 9            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0039944346 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.484        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.5         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00872     |
# |    value_loss           | 65.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 143         |
# | time/                   |             |
# |    fps                  | 1099        |
# |    iterations           | 10          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010413459 |
# |    clip_fraction        | 0.0772      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.558      |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.47        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00569    |
# |    value_loss           | 35.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | 160          |
# | time/                   |              |
# |    fps                  | 1080         |
# |    iterations           | 11           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0059336675 |
# |    clip_fraction        | 0.0478       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.38         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00816     |
# |    value_loss           | 14.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 178          |
# | time/                   |              |
# |    fps                  | 1062         |
# |    iterations           | 12           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0073099714 |
# |    clip_fraction        | 0.0623       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.553       |
# |    explained_variance   | 0.938        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.506        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 9.31         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 195          |
# |    ep_rew_mean          | 195          |
# | time/                   |              |
# |    fps                  | 1063         |
# |    iterations           | 13           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0051209973 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.522       |
# |    explained_variance   | 0.0857       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.6         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00496     |
# |    value_loss           | 22           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 212         |
# |    ep_rew_mean          | 212         |
# | time/                   |             |
# |    fps                  | 1062        |
# |    iterations           | 14          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017247189 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | -1.5        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.143       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00629    |
# |    value_loss           | 3.29        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 230          |
# |    ep_rew_mean          | 230          |
# | time/                   |              |
# |    fps                  | 1061         |
# |    iterations           | 15           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0037203296 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | 0.425        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00433     |
# |    value_loss           | 1.91         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 247          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 1060         |
# |    iterations           | 16           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0021793938 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.515       |
# |    explained_variance   | 0.0201       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.7         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 47.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 266          |
# |    ep_rew_mean          | 266          |
# | time/                   |              |
# |    fps                  | 1061         |
# |    iterations           | 17           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0031491127 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.519       |
# |    explained_variance   | -1.42        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0519       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000763    |
# |    value_loss           | 1.18         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | 282         |
# | time/                   |             |
# |    fps                  | 1065        |
# |    iterations           | 18          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007835402 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.514      |
# |    explained_variance   | 0.0185      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0421      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00915    |
# |    value_loss           | 0.485       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 300          |
# | time/                   |              |
# |    fps                  | 1068         |
# |    iterations           | 19           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0070181834 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.516       |
# |    explained_variance   | 0.0463       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00766      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00275     |
# |    value_loss           | 0.289        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 317          |
# |    ep_rew_mean          | 317          |
# | time/                   |              |
# |    fps                  | 1070         |
# |    iterations           | 20           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0047004893 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.503       |
# |    explained_variance   | 0.301        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0323       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 0.172        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 331         |
# |    ep_rew_mean          | 331         |
# | time/                   |             |
# |    fps                  | 1070        |
# |    iterations           | 21          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004471323 |
# |    clip_fraction        | 0.034       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.485      |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0107      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00139    |
# |    value_loss           | 0.113       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 348         |
# |    ep_rew_mean          | 348         |
# | time/                   |             |
# |    fps                  | 1070        |
# |    iterations           | 22          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008889448 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.491      |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0321      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00433    |
# |    value_loss           | 0.0723      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 365         |
# |    ep_rew_mean          | 365         |
# | time/                   |             |
# |    fps                  | 1072        |
# |    iterations           | 23          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.003554949 |
# |    clip_fraction        | 0.0305      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.489      |
# |    explained_variance   | 0.159       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00815    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00222    |
# |    value_loss           | 0.0442      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 380         |
# |    ep_rew_mean          | 380         |
# | time/                   |             |
# |    fps                  | 1070        |
# |    iterations           | 24          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005943883 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | 0.28        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00548     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0032     |
# |    value_loss           | 0.0268      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 396          |
# |    ep_rew_mean          | 396          |
# | time/                   |              |
# |    fps                  | 1069         |
# |    iterations           | 25           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0035226867 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.473       |
# |    explained_variance   | 0.221        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00807     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 0.0173       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 411          |
# |    ep_rew_mean          | 411          |
# | time/                   |              |
# |    fps                  | 1068         |
# |    iterations           | 26           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0024858676 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.477       |
# |    explained_variance   | 0.0329       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000372     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 8.88e-05     |
# |    value_loss           | 0.0112       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 425        |
# |    ep_rew_mean          | 425        |
# | time/                   |            |
# |    fps                  | 1067       |
# |    iterations           | 27         |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00211124 |
# |    clip_fraction        | 0.0264     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.464     |
# |    explained_variance   | 0.063      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.023     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00129   |
# |    value_loss           | 0.00736    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 434         |
# |    ep_rew_mean          | 434         |
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 28          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.001277355 |
# |    clip_fraction        | 0.0112      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.463      |
# |    explained_variance   | 0.069       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00363    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.000141    |
# |    value_loss           | 0.00484     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 446         |
# |    ep_rew_mean          | 446         |
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 29          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.006993964 |
# |    clip_fraction        | 0.0653      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | 0.0366      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000562   |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00319    |
# |    value_loss           | 0.00324     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 457          |
# |    ep_rew_mean          | 457          |
# | time/                   |              |
# |    fps                  | 1067         |
# |    iterations           | 30           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0045602866 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.485       |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0133      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 0.00218      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 469          |
# |    ep_rew_mean          | 469          |
# | time/                   |              |
# |    fps                  | 1064         |
# |    iterations           | 31           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0046945135 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.496       |
# |    explained_variance   | 0.0997       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0153      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 0.0014       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 478          |
# |    ep_rew_mean          | 478          |
# | time/                   |              |
# |    fps                  | 1063         |
# |    iterations           | 32           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0025761514 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.472       |
# |    explained_variance   | 0.0858       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0118      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00258     |
# |    value_loss           | 0.000998     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 487         |
# |    ep_rew_mean          | 487         |
# | time/                   |             |
# |    fps                  | 1059        |
# |    iterations           | 33          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004733609 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00535     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 0.000668    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 491         |
# |    ep_rew_mean          | 491         |
# | time/                   |             |
# |    fps                  | 1060        |
# |    iterations           | 34          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006527089 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.449      |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00633     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.003      |
# |    value_loss           | 0.000456    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 493         |
# |    ep_rew_mean          | 493         |
# | time/                   |             |
# |    fps                  | 1061        |
# |    iterations           | 35          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.003140565 |
# |    clip_fraction        | 0.0279      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.439      |
# |    explained_variance   | 0.0445      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00302    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00175    |
# |    value_loss           | 0.000335    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 493          |
# |    ep_rew_mean          | 493          |
# | time/                   |              |
# |    fps                  | 1061         |
# |    iterations           | 36           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0032792236 |
# |    clip_fraction        | 0.0497       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.444       |
# |    explained_variance   | 0.221        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00701      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 0.000246     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 496          |
# |    ep_rew_mean          | 496          |
# | time/                   |              |
# |    fps                  | 1062         |
# |    iterations           | 37           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0031621824 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.439       |
# |    explained_variance   | 0.0261       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00923     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 0.000163     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 496          |
# |    ep_rew_mean          | 496          |
# | time/                   |              |
# |    fps                  | 1063         |
# |    iterations           | 38           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0042139655 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.44        |
# |    explained_variance   | 0.0232       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00824     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 0.000133     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 498          |
# |    ep_rew_mean          | 498          |
# | time/                   |              |
# |    fps                  | 1065         |
# |    iterations           | 39           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0031526047 |
# |    clip_fraction        | 0.0475       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.431       |
# |    explained_variance   | 0.0085       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00599      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000605    |
# |    value_loss           | 8.83e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1066         |
# |    iterations           | 40           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0031883214 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.405       |
# |    explained_variance   | 0.23         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00355      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 6.64e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1064         |
# |    iterations           | 41           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0031768633 |
# |    clip_fraction        | 0.0241       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.386       |
# |    explained_variance   | 0.34         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00958     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00296     |
# |    value_loss           | 4.56e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 1063        |
# |    iterations           | 42          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.001850757 |
# |    clip_fraction        | 0.0245      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.372      |
# |    explained_variance   | 0.0637      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00419     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.000807   |
# |    value_loss           | 3.09e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1058         |
# |    iterations           | 43           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0062742783 |
# |    clip_fraction        | 0.0578       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.366       |
# |    explained_variance   | 0.269        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00637      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 2.79e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1055         |
# |    iterations           | 44           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0030417854 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.363       |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00518     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 2.42e-05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 500           |
# |    ep_rew_mean          | 500           |
# | time/                   |               |
# |    fps                  | 1049          |
# |    iterations           | 45            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00095869345 |
# |    clip_fraction        | 0.0118        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.339        |
# |    explained_variance   | 0.115         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.001         |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000448     |
# |    value_loss           | 1.61e-05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1049         |
# |    iterations           | 46           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0047164652 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.331       |
# |    explained_variance   | 0.272        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0108       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 1.15e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1047         |
# |    iterations           | 47           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0020693738 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.324       |
# |    explained_variance   | -0.31        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00571     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000976    |
# |    value_loss           | 8.97e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1046         |
# |    iterations           | 48           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0056365062 |
# |    clip_fraction        | 0.0627       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.32        |
# |    explained_variance   | 0.284        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0138      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 6.07e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1046         |
# |    iterations           | 49           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0010092831 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.313       |
# |    explained_variance   | 0.457        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00469      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -1.89e-05    |
# |    value_loss           | 6.12e-06     |
# ------------------------------------------

# %%
model.save("Models/CartPole")
# Out:
# C:\Users\lk3\source\repos\Python_DataScience_2025_04_16\.venv\Lib\site-packages\stable_baselines3\common\save_util.py:284: UserWarning: Path 'Models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
env = gym.make("CartPole-v1")
model = PPO.load("Models/CartPole", env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
anz = 5
for x in range(anz):
    state = env.reset()[0]  # Startzustand
    score = 0  # Reward Summe
    done = False
    term = False
    
    while (not done) and (not term):
        # env.render()  # Zeichnet die GUI
        action, _ = model.predict(state)
        state, reward, done, term, _ = env.step(action)
        score += reward
    # env.close()
    
    print(f"Punkte: {score}")
# Out:
# Punkte: 500.0
# Punkte: 500.0
# Punkte: 500.0
# Punkte: 500.0
# Punkte: 500.0
