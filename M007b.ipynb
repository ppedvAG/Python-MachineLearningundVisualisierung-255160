# %% [markdown]
# ## Eigene Umgebung
#
# Es kann eine Klasse definiert werden, welche die Oberklasse gym.Env hat
#
# Diese Klasse benötigt die Methoden für Umgebungen (\_\_init\_\_(), step(), reset(), ...)
#
# Sie benötigt außerdem Action Space und Observation Space

# %%
import gymnasium as gym
from gymnasium.spaces import Discrete, Box
import numpy as np

# %% [markdown]
# ### Discrete
#
# Ein einzelner Wert von X bis Y

# %%
d = Discrete(3, start=-1)

# %%
d.sample()
# Out:
# np.int64(0)

# %% [markdown]
# ### Box
#
# Bereich von X bis Y
#
# Standardmäßig float32, kann angepasst werden
#
# Kann auch mehrere Werte zurückgeben (size=)

# %%
b = Box(0, 100, dtype=np.int8, shape=(10, 3))

# %%
b.sample()
# Out:
# array([[35, 15, 58],
#        [17, 32, 81],
#        [ 2, 19, 41],
#        [84, 26, 81],
#        [58,  4, 97],
#        [24, 18, 13],
#        [69, 59, 54],
#        [48,  1, 52],
#        [ 2, 98, 99],
#        [ 2, 86, 84]], dtype=int8)

# %% [markdown]
# ### CarDriver
#
# Soll eine Geschwindigkeit um 50km/h halten
#
# Kann über Actions beschleunigen, bremsen oder nichts tun

# %%
class CarDriver(gym.Env):
    def __init__(self):
        self.action_space = Discrete(3)  # 0: Bremsen, 1: Nichts Tun, 2: Beschleunigen
        self.observation_space = Box(0, 100, dtype=np.int8)  # 0-100km/h möglich
        self.state = 50  # Startgeschwindigkeit
        self.end_time = 100  # Maximale Dauer einer Umgebung (auch Maximalpunktzahl)
        self.time_now = 0

    
    def step(self, action):
        self.state += (action - 1) * 3

        reward = 0
        if self.state >= 45 and self.state <= 55:
            reward += 1

        self.state += (np.random.randint(5) - 2)  # Random Noise
        self.time_now += 1

        if self.state < 0:
            self.state = 0
        if self.state > 100:
            self.state = 100

        return np.array([self.state], dtype=np.int8), \
                reward, \
                self.time_now >= self.end_time, \
                self.time_now >= self.end_time, \
                {"V": self.state}

    
    def reset(self, seed=0):
        self.state = 50
        self.time_now = 0
        return (np.array([self.state], dtype=np.int8), {})

# %% [markdown]
# ### check_env

# %%
env = CarDriver()

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env)

# %% [markdown]
# ### Eigene Umgebung Testen

# %%
anz = 10
for x in range(anz):
    state = env.reset()  # Startzustand
    score = 0  # Reward Summe
    done = False
    velocities = []
    
    while not done:
        action = env.action_space.sample()
        state, reward, done, _, info = env.step(action)
        score += reward
        velocities.append(int(info["V"]))
    
    print(f"Punkte: {score}, {velocities}")
# Out:
# Punkte: 21, [50, 51, 50, 51, 55, 55, 54, 51, 52, 47, 47, 42, 41, 43, 40, 39, 38, 42, 39, 38, 40, 38, 40, 39, 39, 44, 47, 43, 45, 45, 47, 50, 48, 43, 44, 43, 42, 44, 44, 42, 39, 34, 30, 30, 33, 33, 31, 30, 25, 23, 22, 21, 22, 22, 27, 27, 26, 22, 20, 21, 23, 20, 22, 21, 25, 30, 27, 22, 27, 26, 24, 26, 24, 26, 28, 23, 27, 32, 33, 34, 38, 36, 35, 34, 29, 28, 32, 31, 29, 30, 34, 35, 37, 39, 41, 43, 42, 45, 47, 45]
# Punkte: 43, [48, 45, 40, 35, 32, 30, 29, 31, 31, 27, 32, 35, 36, 39, 36, 38, 36, 34, 38, 37, 39, 36, 36, 33, 36, 34, 35, 37, 38, 39, 43, 46, 47, 49, 47, 46, 47, 44, 49, 51, 52, 55, 57, 58, 60, 58, 61, 60, 63, 65, 60, 55, 55, 52, 48, 48, 50, 53, 52, 50, 48, 52, 53, 52, 50, 53, 51, 55, 54, 57, 55, 53, 54, 59, 59, 56, 60, 60, 60, 57, 56, 54, 58, 60, 55, 55, 53, 50, 51, 49, 53, 54, 55, 57, 54, 56, 58, 57, 52, 51]
# Punkte: 12, [48, 43, 48, 45, 47, 42, 44, 42, 41, 43, 41, 40, 40, 36, 38, 36, 35, 33, 35, 33, 29, 27, 29, 27, 31, 26, 31, 36, 37, 32, 30, 34, 36, 31, 31, 36, 34, 35, 30, 29, 34, 33, 35, 35, 38, 35, 31, 28, 31, 28, 30, 35, 39, 40, 44, 44, 45, 40, 41, 41, 44, 44, 48, 45, 47, 45, 46, 48, 46, 41, 42, 43, 41, 37, 34, 38, 37, 41, 40, 39, 40, 38, 34, 38, 36, 36, 31, 31, 36, 35, 37, 36, 37, 38, 33, 35, 40, 39, 40, 41]
# Punkte: 15, [55, 52, 57, 56, 56, 60, 56, 56, 57, 56, 55, 57, 53, 51, 50, 48, 48, 52, 56, 54, 56, 58, 62, 66, 67, 72, 70, 66, 69, 67, 69, 64, 68, 73, 72, 77, 82, 77, 78, 82, 84, 85, 87, 89, 87, 88, 89, 84, 82, 87, 92, 91, 92, 90, 94, 95, 97, 98, 98, 99, 100, 102, 103, 105, 108, 106, 109, 109, 108, 109, 111, 110, 111, 113, 109, 107, 111, 109, 114, 113, 109, 107, 108, 110, 111, 112, 108, 109, 109, 107, 105, 109, 107, 111, 109, 108, 109, 113, 115, 119]
# Punkte: 4, [52, 50, 51, 47, 44, 40, 40, 38, 39, 42, 40, 38, 39, 37, 42, 40, 38, 42, 38, 38, 38, 36, 32, 36, 36, 34, 33, 34, 31, 34, 31, 36, 38, 36, 40, 35, 33, 34, 29, 33, 28, 32, 27, 25, 23, 24, 19, 24, 22, 21, 22, 20, 16, 16, 17, 18, 17, 12, 16, 16, 21, 26, 25, 24, 21, 20, 18, 17, 18, 22, 21, 18, 21, 26, 30, 32, 30, 31, 30, 34, 29, 28, 29, 29, 33, 34, 33, 31, 28, 29, 31, 33, 35, 37, 36, 37, 35, 36, 36, 39]

# %% [markdown]
# ### PPO

# %%
from stable_baselines3 import PPO
env = CarDriver()

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 19.6     |
# | time/              |          |
# |    fps             | 2366     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 21.8        |
# | time/                   |             |
# |    fps                  | 1426        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012212638 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.000634    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.31        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0069     |
# |    value_loss           | 10.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 22.2        |
# | time/                   |             |
# |    fps                  | 1269        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012940921 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.0218      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.07        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00799    |
# |    value_loss           | 14.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 22.8        |
# | time/                   |             |
# |    fps                  | 1201        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012246378 |
# |    clip_fraction        | 0.0616      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0478      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.08        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00581    |
# |    value_loss           | 14.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 24.5        |
# | time/                   |             |
# |    fps                  | 1138        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010324182 |
# |    clip_fraction        | 0.0249      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0919      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.96        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00351    |
# |    value_loss           | 20.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 28.4         |
# | time/                   |              |
# |    fps                  | 1113         |
# |    iterations           | 6            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0043045855 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.0497      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.88         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00309     |
# |    value_loss           | 20.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 30.9        |
# | time/                   |             |
# |    fps                  | 1069        |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012292391 |
# |    clip_fraction        | 0.0711      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0744      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00532    |
# |    value_loss           | 28.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 34.7        |
# | time/                   |             |
# |    fps                  | 1034        |
# |    iterations           | 8           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008526234 |
# |    clip_fraction        | 0.0512      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.0423      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00395    |
# |    value_loss           | 30          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 38.3        |
# | time/                   |             |
# |    fps                  | 1037        |
# |    iterations           | 9           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005849777 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.0275      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.5        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00076    |
# |    value_loss           | 36.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 40.4        |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 10          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011363887 |
# |    clip_fraction        | 0.0852      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0063     |
# |    value_loss           | 31          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 44.4         |
# | time/                   |              |
# |    fps                  | 1050         |
# |    iterations           | 11           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0045912312 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.0359       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.8         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 41.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 48.1        |
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 12          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010457862 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.00203    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00572    |
# |    value_loss           | 41.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 52.7         |
# | time/                   |              |
# |    fps                  | 1049         |
# |    iterations           | 13           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0047087707 |
# |    clip_fraction        | 0.0939       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.0109       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.9         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00456     |
# |    value_loss           | 51.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 56.9        |
# | time/                   |             |
# |    fps                  | 1053        |
# |    iterations           | 14          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008085018 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.0208      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.2        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00444    |
# |    value_loss           | 56.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 61.3        |
# | time/                   |             |
# |    fps                  | 1050        |
# |    iterations           | 15          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011024363 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.0038      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00219    |
# |    value_loss           | 61.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 63          |
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 16          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010463506 |
# |    clip_fraction        | 0.0963      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.00645     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.4        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00151     |
# |    value_loss           | 66.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 65.9        |
# | time/                   |             |
# |    fps                  | 1048        |
# |    iterations           | 17          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010101449 |
# |    clip_fraction        | 0.0468      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.00896     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.1        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00241    |
# |    value_loss           | 67.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 67.6         |
# | time/                   |              |
# |    fps                  | 1040         |
# |    iterations           | 18           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0065525426 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.0165       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.3         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00304     |
# |    value_loss           | 76.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 68.9        |
# | time/                   |             |
# |    fps                  | 1042        |
# |    iterations           | 19          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010114735 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.00597    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36          |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.000501    |
# |    value_loss           | 76.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 70.8        |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 20          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007739906 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.00308     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.2        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.000532    |
# |    value_loss           | 79.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 72.7         |
# | time/                   |              |
# |    fps                  | 1045         |
# |    iterations           | 21           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0060385913 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.00453      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.8         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 90.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 74.1         |
# | time/                   |              |
# |    fps                  | 1041         |
# |    iterations           | 22           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0063244333 |
# |    clip_fraction        | 0.0742       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.0123       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.5         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000844    |
# |    value_loss           | 96.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 76.4        |
# | time/                   |             |
# |    fps                  | 1039        |
# |    iterations           | 23          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.005179148 |
# |    clip_fraction        | 0.0429      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.0134      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.6        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000389   |
# |    value_loss           | 95.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 77.5        |
# | time/                   |             |
# |    fps                  | 1042        |
# |    iterations           | 24          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.014885947 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.00338    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.5        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00185     |
# |    value_loss           | 100         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 78.4         |
# | time/                   |              |
# |    fps                  | 1045         |
# |    iterations           | 25           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0047246013 |
# |    clip_fraction        | 0.161        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.000266     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.3         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.00429      |
# |    value_loss           | 100          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 100       |
# |    ep_rew_mean          | 77.8      |
# | time/                   |           |
# |    fps                  | 1046      |
# |    iterations           | 26        |
# |    time_elapsed         | 50        |
# |    total_timesteps      | 53248     |
# | train/                  |           |
# |    approx_kl            | 0.0404935 |
# |    clip_fraction        | 0.107     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.01     |
# |    explained_variance   | -0.00375  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 53.8      |
# |    n_updates            | 250       |
# |    policy_gradient_loss | 0.00144   |
# |    value_loss           | 111       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 77.4        |
# | time/                   |             |
# |    fps                  | 1047        |
# |    iterations           | 27          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007814947 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.0184     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63          |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.003      |
# |    value_loss           | 107         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 78.2        |
# | time/                   |             |
# |    fps                  | 1048        |
# |    iterations           | 28          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.007936182 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.00844     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.8        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00169     |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 79.4        |
# | time/                   |             |
# |    fps                  | 1050        |
# |    iterations           | 29          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.012670498 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.00777    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.3        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.000591   |
# |    value_loss           | 107         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 80.6        |
# | time/                   |             |
# |    fps                  | 1047        |
# |    iterations           | 30          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009928959 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.00509    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.7        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00333     |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 83.7        |
# | time/                   |             |
# |    fps                  | 1046        |
# |    iterations           | 31          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008844062 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -0.00384    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.6        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00395     |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 85.5        |
# | time/                   |             |
# |    fps                  | 1046        |
# |    iterations           | 32          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008304372 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.00203     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.2        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00268     |
# |    value_loss           | 124         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 85.3         |
# | time/                   |              |
# |    fps                  | 1046         |
# |    iterations           | 33           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0069835326 |
# |    clip_fraction        | 0.0807       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | -0.00732     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.2         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 0.00203      |
# |    value_loss           | 126          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 85.7        |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 34          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006591773 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.0015      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.6        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.000626    |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 86          |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 35          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013926242 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.984      |
# |    explained_variance   | -0.00194    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.1        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.000702    |
# |    value_loss           | 129         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 85.8        |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 36          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.007066168 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.973      |
# |    explained_variance   | -0.0076     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.4        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00269     |
# |    value_loss           | 123         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 86.4         |
# | time/                   |              |
# |    fps                  | 1043         |
# |    iterations           | 37           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0075830636 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.986       |
# |    explained_variance   | -1.24e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53           |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.00211      |
# |    value_loss           | 132          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 86.6        |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 38          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.022047404 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.981      |
# |    explained_variance   | -0.000145   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.2        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00502     |
# |    value_loss           | 122         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 86         |
# | time/                   |            |
# |    fps                  | 1041       |
# |    iterations           | 39         |
# |    time_elapsed         | 76         |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.00778572 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.998     |
# |    explained_variance   | 0.000261   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 75         |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00215   |
# |    value_loss           | 133        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 85.5        |
# | time/                   |             |
# |    fps                  | 1036        |
# |    iterations           | 40          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006894196 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | -0.000898   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.9        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00223     |
# |    value_loss           | 127         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 83.5        |
# | time/                   |             |
# |    fps                  | 1032        |
# |    iterations           | 41          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.030159995 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.00239     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.5        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00258     |
# |    value_loss           | 128         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 76.5        |
# | time/                   |             |
# |    fps                  | 1032        |
# |    iterations           | 42          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.024289135 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0.0154      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.2        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.000588    |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 72.5        |
# | time/                   |             |
# |    fps                  | 1032        |
# |    iterations           | 43          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008605041 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | 0.0175      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.6        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00199    |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 69.1         |
# | time/                   |              |
# |    fps                  | 1031         |
# |    iterations           | 44           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0140311625 |
# |    clip_fraction        | 0.139        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.97        |
# |    explained_variance   | 0.0284       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.6         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00579     |
# |    value_loss           | 92.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 68.1        |
# | time/                   |             |
# |    fps                  | 1032        |
# |    iterations           | 45          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.006235143 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.959      |
# |    explained_variance   | 0.0139      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.9        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00046    |
# |    value_loss           | 90.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 70.4        |
# | time/                   |             |
# |    fps                  | 1032        |
# |    iterations           | 46          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.007893997 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.948      |
# |    explained_variance   | 0.031       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.4        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00322    |
# |    value_loss           | 96.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 76.3         |
# | time/                   |              |
# |    fps                  | 1033         |
# |    iterations           | 47           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0048144334 |
# |    clip_fraction        | 0.0812       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.923       |
# |    explained_variance   | -0.00456     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.2         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 0.00184      |
# |    value_loss           | 108          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 80.2         |
# | time/                   |              |
# |    fps                  | 1033         |
# |    iterations           | 48           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0072444747 |
# |    clip_fraction        | 0.0846       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.913       |
# |    explained_variance   | -0.00756     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.3         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.00015      |
# |    value_loss           | 103          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 83.5         |
# | time/                   |              |
# |    fps                  | 1030         |
# |    iterations           | 49           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0032782983 |
# |    clip_fraction        | 0.0701       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.9         |
# |    explained_variance   | -0.00479     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.9         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.00291      |
# |    value_loss           | 115          |
# ------------------------------------------

# %%
model.save("Models/CarDriver")

# %%
env = CarDriver()
model = PPO.load("Models/CarDriver", env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
anz = 10
for x in range(anz):
    state = env.reset()[0]  # Startzustand
    score = 0  # Reward Summe
    done = False
    velocities = []
    
    while not done:
        action = model.predict(state)
        state, reward, done, _, info = env.step(action[0])
        score += reward
        velocities.append(int(info["V"]))
    
    print(f"Punkte: {score},\n {velocities}")
# Out:
# Punkte: 92,
#  [52, 50, 45, 43, 48, 44, 45, 46, 50, 49, 52, 53, 49, 49, 51, 56, 54, 56, 56, 55, 53, 54, 56, 56, 51, 53, 55, 54, 55, 55, 57, 59, 54, 51, 52, 50, 48, 47, 51, 49, 51, 52, 52, 53, 55, 51, 53, 55, 53, 49, 54, 52, 48, 51, 52, 53, 55, 50, 54, 52, 54, 52, 49, 47, 47, 48, 50, 51, 49, 54, 52, 51, 48, 47, 49, 54, 54, 51, 48, 46, 46, 46, 45, 43, 45, 45, 46, 46, 45, 43, 45, 50, 50, 49, 47, 52, 53, 50, 50, 48]
# Punkte: 90,
#  [48, 43, 46, 48, 48, 51, 53, 49, 48, 52, 54, 58, 56, 52, 48, 53, 54, 55, 51, 48, 45, 49, 53, 50, 49, 48, 51, 46, 44, 48, 51, 49, 50, 51, 49, 49, 47, 48, 47, 49, 48, 51, 50, 51, 50, 49, 48, 47, 50, 52, 51, 52, 57, 55, 54, 51, 56, 51, 54, 53, 52, 54, 49, 50, 51, 50, 48, 48, 50, 45, 44, 42, 41, 44, 46, 45, 44, 44, 46, 48, 50, 54, 55, 55, 54, 57, 53, 54, 52, 53, 55, 53, 55, 52, 54, 54, 54, 49, 51, 50]
# Punkte: 91,
#  [52, 52, 50, 49, 50, 48, 44, 44, 46, 48, 50, 51, 50, 48, 46, 47, 47, 48, 50, 48, 44, 43, 47, 43, 47, 48, 46, 47, 48, 47, 49, 45, 46, 48, 50, 50, 48, 47, 51, 53, 53, 58, 54, 52, 56, 52, 52, 51, 54, 56, 55, 56, 57, 53, 51, 49, 50, 48, 48, 49, 44, 46, 49, 48, 50, 50, 52, 50, 48, 51, 52, 51, 50, 48, 52, 53, 55, 50, 48, 47, 46, 45, 44, 46, 43, 45, 43, 48, 46, 46, 51, 50, 52, 50, 52, 54, 53, 52, 53, 52]
# Punkte: 70,
#  [45, 44, 45, 44, 42, 45, 45, 46, 45, 43, 44, 44, 40, 42, 41, 43, 43, 44, 44, 42, 44, 42, 41, 42, 43, 45, 43, 41, 43, 45, 46, 44, 44, 44, 46, 45, 43, 44, 45, 43, 46, 45, 45, 45, 47, 47, 47, 47, 46, 48, 49, 48, 46, 47, 49, 46, 46, 50, 46, 44, 42, 40, 42, 44, 44, 46, 50, 51, 52, 53, 53, 53, 52, 56, 54, 54, 52, 54, 52, 53, 55, 52, 49, 50, 51, 50, 51, 53, 51, 49, 47, 48, 49, 53, 51, 56, 54, 51, 50, 48]
# Punkte: 84,
#  [48, 47, 50, 49, 47, 46, 49, 47, 45, 49, 54, 59, 61, 65, 64, 62, 60, 59, 57, 52, 51, 53, 52, 54, 56, 54, 52, 53, 49, 49, 51, 52, 51, 52, 54, 53, 52, 54, 53, 52, 54, 52, 50, 52, 52, 48, 51, 51, 50, 52, 52, 53, 54, 52, 52, 50, 51, 52, 52, 48, 48, 53, 50, 48, 48, 48, 47, 46, 44, 48, 50, 54, 53, 53, 54, 59, 58, 54, 55, 57, 53, 52, 50, 51, 48, 49, 48, 51, 52, 54, 54, 58, 58, 58, 57, 59, 57, 52, 52, 53]
